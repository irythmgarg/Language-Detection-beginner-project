# %%
import pandas as pd  # Import pandas for data manipulation and analysis
import numpy as np  # Import NumPy for numerical operations
import matplotlib.pyplot as plt  # Import Matplotlib for plotting
import seaborn as sns  # Import Seaborn for advanced data visualization

# %%
df=pd.read_csv('/content/language.csv')  # Read the CSV file into a DataFrame named 'df'

# %%
df.shape # dimensions
# Out:
# (22000, 2)

# %%
df.head(); # first 5 rows of dataset
# Out:
#                                                 Text  language
# 0  klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1  sebes joseph pereira thomas  på eng the jesuit...   Swedish
# 2  ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เ...      Thai
# 3  விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...     Tamil
# 4  de spons behoort tot het geslacht haliclona en...     Dutch

# %%
df.language.value_counts()  # Count the occurrences of each unique value in the 'language' column
# Out:
# language
# Estonian      1000
# Swedish       1000
# Thai          1000
# Tamil         1000
# Dutch         1000
# Japanese      1000
# Turkish       1000
# Latin         1000
# Urdu          1000
# Indonesian    1000
# Portugese     1000
# French        1000
# Chinese       1000
# Korean        1000
# Hindi         1000
# Spanish       1000
# Pushto        1000
# Persian       1000
# Romanian      1000
# Russian       1000
# English       1000
# Arabic        1000
# Name: count, dtype: int64

# %%
df.isna().sum() # no null values
# Out:
# Text        0
# language    0
# dtype: int64

# %% [markdown]
# # **Convert text data into numeric form using CountVectorizer**

# %%
from sklearn.feature_extraction.text import CountVectorizer  # For converting text to numeric features
from sklearn.model_selection import train_test_split  # For splitting data into training and testing sets
from sklearn.naive_bayes import MultinomialNB  # Naive Bayes classifier for multinomially distributed data

# %%
x = np.array(df['Text'])  # Convert the 'Text' column of the DataFrame to a NumPy array (features)
y = np.array(df['language'])  # Convert the 'language' column to a NumPy array (labels)

# %%
x # array to scripts
# Out:
# array(['klement gottwaldi surnukeha palsameeriti ning paigutati mausoleumi surnukeha oli aga liiga hilja ja oskamatult palsameeritud ning hakkas ilmutama lagunemise tundemärke  aastal viidi ta surnukeha mausoleumist ära ja kremeeriti zlíni linn kandis aastatel – nime gottwaldov ukrainas harkivi oblastis kandis zmiivi linn aastatel – nime gotvald',
#        'sebes joseph pereira thomas  på eng the jesuits and the sino-russian treaty of nerchinsk  the diary of thomas pereira bibliotheca instituti historici s i --   rome libris ',
#        'ถนนเจริญกรุง อักษรโรมัน thanon charoen krung เริ่มตั้งแต่ถนนสนามไชยถึงแม่น้ำเจ้าพระยาที่ถนนตก กรุงเทพมหานคร เป็นถนนรุ่นแรกที่ใช้เทคนิคการสร้างแบบตะวันตก ปัจจุบันผ่านพื้นที่เขตพระนคร เขตป้อมปราบศัตรูพ่าย เขตสัมพันธวงศ์ เขตบางรัก เขตสาทร และเขตบางคอแหลม',
#        ...,
# ...

# %%
y # array of languages
# Out:
# array(['Estonian', 'Swedish', 'Thai', ..., 'Spanish', 'Chinese',
#        'Romanian'], dtype=object)

# %%
cv=CountVectorizer()  # Create an instance of CountVectorizer for text feature extraction
X = cv.fit_transform(x)  # Fit the CountVectorizer on the text data and transform it into a feature matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)  # Split the data into training and testing sets

# %%
print(x_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 613529 stored elements and shape (14740, 277720)>
#   Coords	Values
#   (0, 197295)	2
#   (0, 197708)	1
#   (0, 197801)	1
#   (0, 198388)	1
#   (0, 197467)	1
#   (0, 197865)	2
#   (0, 197604)	1
#   (0, 198428)	1
#   (0, 198501)	1
#   (0, 198556)	1
#   (0, 197332)	1
#   (0, 197485)	2
#   (0, 198123)	1
#   (0, 197892)	1
#   (0, 197990)	1
#   (0, 198053)	1
#   (0, 198417)	1
#   (0, 197623)	1
#   (1, 197641)	2
#   (1, 197314)	1
#   (1, 197931)	1
#   (1, 197804)	3
#   (1, 198397)	1
#   (1, 197149)	1
#   (1, 197781)	1
#   :	:
#   (14738, 188817)	1
#   (14738, 192004)	1
#   (14738, 157171)	1
#   (14738, 190346)	1
#   (14738, 190725)	1
#   (14738, 189685)	1
#   (14738, 159269)	2
#   (14738, 145431)	1
#   (14738, 173292)	1
#   (14738, 176062)	1
#   (14738, 159959)	1
#   (14738, 190198)	1
#   (14738, 167124)	1
#   (14738, 168158)	1
#   (14738, 180260)	2
#   (14738, 153262)	1
#   (14738, 162150)	1
#   (14738, 153355)	1
# ...

# %%
model=MultinomialNB()  # Create an instance of the Multinomial Naive Bayes classifier
model.fit(x_train,y_train)  # Train the classifier on the training data
# Out:
# MultinomialNB()

# %%
model.score(x_test,y_test)  # Evaluate the classifier's accuracy on the testing data
# Out:
# 0.953168044077135

# %%
user=input("Enter a text");
data=cv.transform([user]).toarray()
output=model.predict(data)
print(output)
# Out:
# Enter a text qué estás haciendo
# ['Spanish']
